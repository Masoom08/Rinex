# %%
print("Hello World")
# Out:
# Hello World

# %%
#variable and data type

# %%
a=1
b=1.0
c='a'
d="word"
e="i am a girl"
f= True
print (type(a),type(b),type(c),type(d),type(e),type(f))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'str'> <class 'str'> <class 'bool'>

# %%
# input functions
# loop
#condition
#string

# %%
name= input()
print(name)
print(type(name))  #data type always string by default
# Out:
# 3
# 3
# <class 'str'>

# %%
a=input()
b=input()
add= a+b
print(add)
# Out:
# 11
# 22
# 1122

# %%
print(11+22)
# Out:
# 33

# %%
print("11"+"22")
# Out:
# 1122

# %%
a=int(input())
b=int(input())
add = a+b
print(add)
# Out:
# 11
# 22
# 33

# %%
# boolean data type
x = 0
print(bool(x))
# Out:
# False

# %%
x=10
print(bool(x))
print(int(x))
print(str(x))
# Out:
# True
# 10
# 10

# %%
# conditions
num = 12
remainder=num%2
if(remainder==0):
  print("it is an even no.")
else:
  print("odd no.")
# Out:
# it is an even no.

# %%
# weather conditions
con = input("enter the weather condition  ").lower()  #CASE SENSITIVE
if (con=="sunny"):
  print("summer season")
elif (con=="cold"):
  print("winter season")
elif con=="rain"or con=="thunder":
  print("monsoon season")
else:
  print("wrong data")
# Out:
# enter the weather condition  SUNNY
# summer season

# %%
#string
a=2
b="number"
print(str(a)+" is a "+b)
# Out:
# 2 is a number

# %%
a=2
b ="number"
print(f'{a} is a {b}')
# Out:
# 2 is a number

# %%
a=int(input())
b=int(input())
c=a+b
print(F"{c} is the sum of {a} and {b}")
# Out:
# 11
# 12
# 23 is the sum of 11 and 12

# %%
name= "masoom"
print(type(name))
age=18
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print(f'the age of {name} is {age}')
# Out:
# the age of masoom is 18

# %%
#looping construction
#iteration
#repetition
# 1.for loop 2. while loop


print("masoom "*5)  #repetition
# Out:
# masoom masoom masoom masoom masoom

# %%
i=0
while(i<=4):
  print(i,end="") #by default without end line by line
  i+=1
# Out:
# 01234

# %%
#range - start,stop,step
#for  loop and list n tupple

for i in range(5):
  print(i,end=" ")
# Out:
# 0 1 2 3 4

# %%
for i in range(2,6):
  print(i,end=" ")
# Out:
# 2 3 4 5

# %%
for i in range(0,10,2):
  print(i,end=" ")
# Out:
# 0 2 4 6 8

# %%
#mutiplication table
n=int(input("enter a no."))
for i in range(1,11):
  print( F'{n} *  {i} = {i*n}')
# Out:
# enter a no.7
# 7 *  1 = 7
# 7 *  2 = 14
# 7 *  3 = 21
# 7 *  4 = 28
# 7 *  5 = 35
# 7 *  6 = 42
# 7 *  7 = 49
# 7 *  8 = 56
# 7 *  9 = 63
# 7 *  10 = 70

# %%
#list and tupple
a= [5,10,15,20]
b= {5,10,15,20}
print (a)
print(type(a))
print (b)
print(type(b))
# Out:
# [5, 10, 15, 20]
# <class 'list'>
# {10, 20, 5, 15}
# <class 'set'>

# %%
len(a)
# Out:
# 4

# %%
#indexing
a[0] # index is 0-3
# Out:
# 5

# %%
a[0]=90  #list is mutable
a
# Out:
# [90, 10, 15, 20]

# %%
a= (5,13,14,15)
print(a)         #tuple
print(type(a))
# Out:
# (5, 13, 14, 15)
# <class 'tuple'>

# %%
a(0)=12
a
# Out:
#   File "<ipython-input-42-58182e4e120e>", line 1
#     a(0)=12
#     ^
# SyntaxError: cannot assign to function call

# %%
#tuple is immutable

# %%
#list using for loop

# %%
a=[1,"python",1.0,True]
for i in a:
  print(F'{i} is belonging to {type(i)}') # this is iteration
# Out:
# 1 is belonging to <class 'int'>
# python is belonging to <class 'str'>
# 1.0 is belonging to <class 'float'>
# True is belonging to <class 'bool'>

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(2,6))
# Out:
# [2, 3, 4, 5]

# %%
list(range(1,10,2))
# Out:
# [1, 3, 5, 7, 9]

# %%
a=[1,2,3,4,5]
print(len(a))
a.append(6)
print(len(a))
a
# Out:
# 5
# 6
# [1, 2, 3, 4, 5, 6]

# %%
i=40
while(i>=20):
  print(i)
  i-=2
# Out:
# 40
# 38
# 36
# 34
# 32
# 30
# 28
# 26
# 24
# 22
# 20

# %%
for i in range(40,19,-2):
  print(i,end=" ")
# Out:
# 40 38 36 34 32 30 28 26 24 22 20

# %%
def add(a,b):
  print(a+b)

a=10
b=20
add(a,b)
# Out:
# 30
