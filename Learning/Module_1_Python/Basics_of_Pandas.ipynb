# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#open source for analytics
#data ingestion or collection
#data manioulation or precombination

#data frame = matrics
#series = vector

# %%
import numpy as np
a= np.array(['Ameer','John','Prateek']) # we use array i  numpy
print (a)
print (type(a))
# Out:
# ['Ameer' 'John' 'Prateek']
# <class 'numpy.ndarray'>

# %%
#indexing of array in pandas
b= pd.Series(['Ameer','John','Prateek'])   # we use Series in pandas
print (b)
print (type(b))
# Out:
# 0      Ameer
# 1       John
# 2    Prateek
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
#fancy indexing array in pandas
a[0]
# Out:
# 'Ameer'

# %%
import numpy as np
b= pd.Series(['Ameer','John','Prateek'],index=['A','B','C'])
print (b)
print (type(b))
# Out:
# A      Ameer
# B       John
# C    Prateek
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
#Data ingestion
d={'Name':['a','b','c'],
   'age':[25,30,19],
   'weight':[49,50,62]}
print (d)
print (type(d))     # dictionary
# Out:
# {'Name': ['a', 'b', 'c'], 'age': [25, 30, 19], 'weight': [49, 50, 62]}
# <class 'dict'>

# %%
df=pd.DataFrame(d)  # data frame
df
# Out:
#   Name  age  weight
# 0    a   25      49
# 1    b   30      50
# 2    c   19      62

# %%
type(df)   # data type
# Out:
# pandas.core.frame.DataFrame

# %%
df.ndim    # two dimensional
# Out:
# 2

# %%
df.iloc[0]
# Out:
# Name       a
# age       25
# weight    49
# Name: 0, dtype: object

# %%
df['weight']
# Out:
# 0    49
# 1    50
# 2    62
# Name: weight, dtype: int64

# %%
df= pd.read_csv('/content/student_admission_record_dirty.csv')
df
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# 3      Aliya  17.0    Male                  55.0                   85.29
# 4      Bilal  20.0    Male                  65.0                   61.13
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0                   78.09
# 153    Bilal  17.0  Female                  81.0                   84.40
# 154   Fatima  21.0  Female                  98.0                   50.86
# 155   Shoaib  -1.0    Male                  91.0                   80.12
# 156     Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
df.head()
# Out:
#       Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0  Shehroz  24.0  Female                  50.0                   68.90
# 1    Waqar  21.0  Female                  99.0                   60.73
# 2   Bushra  17.0    Male                  89.0                     NaN
# 3    Aliya  17.0    Male                  55.0                   85.29
# 4    Bilal  20.0    Male                  65.0                   61.13
#
#         City Admission Status
# 0     Quetta         Rejected
# 1    Karachi              NaN
# 2  Islamabad         Accepted
# 3    Karachi         Rejected
# 4     Lahore              NaN

# %%
df.tail()
# Out:
#        Name   Age  Gender  Admission Test Score  High School Percentage  \
# 152     Ali  19.0  Female                  85.0                   78.09
# 153   Bilal  17.0  Female                  81.0                   84.40
# 154  Fatima  21.0  Female                  98.0                   50.86
# 155  Shoaib  -1.0    Male                  91.0                   80.12
# 156    Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# 152     Quetta         Accepted
# 153  Islamabad         Rejected
# 154     Multan         Accepted
# 155     Quetta         Accepted
# 156     Lahore         Accepted

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    147 non-null    object
#  1   Age                     147 non-null    float64
#  2   Gender                  147 non-null    object
#  3   Admission Test Score    146 non-null    float64
#  4   High School Percentage  146 non-null    float64
#  5   City                    147 non-null    object
#  6   Admission Status        147 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 8.7+ KB

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# 3      Aliya  17.0    Male                  55.0                   85.29
# 4      Bilal  20.0    Male                  65.0                   61.13
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0                   78.09
# 153    Bilal  17.0  Female                  81.0                   84.40
# 154   Fatima  21.0  Female                  98.0                   50.86
# 155   Shoaib  -1.0    Male                  91.0                   80.12
# 156     Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# ...

# %%
df['City'].unique
# Out:
# <bound method Series.unique of 0         Quetta
# 1        Karachi
# 2      Islamabad
# 3        Karachi
# 4         Lahore
#          ...
# 152       Quetta
# 153    Islamabad
# 154       Multan
# 155       Quetta
# 156       Lahore
# Name: City, Length: 157, dtype: object>

# %%
df['City'].value_counts()
# Out:
# City
# Quetta        30
# Karachi       28
# Multan        21
# Peshawar      18
# Islamabad     17
# Lahore        17
# Rawalpindi    16
# Name: count, dtype: int64

# %%
max=df['High School Percentage'].max()
df[df['High School Percentage']==max]
# Out:
#       Name   Age  Gender  Admission Test Score  High School Percentage  \
# 47  Maryam  19.0  Female                  74.0                   110.5
#
#       City Admission Status
# 47  Lahore         Accepted

# %%
df1= pd.read_csv('/content/mentalhealth_dataset.csv')
df1
# Out:
#       Timestamp  Gender  Age           Course YearOfStudy  CGPA  Depression  \
# 0     13/7/2020  Female   24    Biotechnology      Year 3  2.38           1
# 1     13/7/2020  Female   18    Biotechnology      Year 3  4.00           0
# 2     13/7/2020  Female   25    Biotechnology      Year 3  3.68           0
# 3     13/7/2020  Female   18      Engineering      year 4  4.00           0
# 4     13/7/2020  Female   20      Engineering      year 4  2.00           1
# ..          ...     ...  ...              ...         ...   ...         ...
# 995  2023-07-09  Female   20              KOE      year 1  2.31           0
# 996  2023-07-09  Female   23      Engineering      year 1  3.72           1
# 997  2023-07-09  Female   19  Human Sciences       Year 2  2.00           0
# 998  2023-07-09  Female   24  Human Sciences       Year 2  3.89           1
# 999  2023-07-09  Female   20  Human Sciences       Year 2  2.46           1
#
# ...

# %%
x=df1['YearOfStudy'][0]
x
# Out:
# 'Year 3'

# %%
x.split()
# Out:
# ['Year', '3']

# %%
x.split()[1]
# Out:
# '3'

# %%
#df1['YearOfStudy']=df['YearOfStudy'].apply(lambda x:x.split()[1].replace(',','')).astype('int')

# %%
df1.head()
# Out:
#    Timestamp  Gender  Age         Course YearOfStudy  CGPA  Depression  \
# 0  13/7/2020  Female   24  Biotechnology      Year 3  2.38           1
# 1  13/7/2020  Female   18  Biotechnology      Year 3  4.00           0
# 2  13/7/2020  Female   25  Biotechnology      Year 3  3.68           0
# 3  13/7/2020  Female   18    Engineering      year 4  4.00           0
# 4  13/7/2020  Female   20    Engineering      year 4  2.00           1
#
#    Anxiety  PanicAttack  SpecialistTreatment  SymptomFrequency_Last7Days  \
# 0        0            0                    0                           5
# 1        1            0                    0                           0
# 2        0            1                    0                           3
# 3        0            0                    0                           3
# 4        1            0                    0                           0
#
#    HasMentalHealthSupport  SleepQuality  StudyStressLevel  StudyHoursPerWeek  \
# ...

# %%
df1[df1['CGPA']==df1['CGPA'].max()]
# Out:
#       Timestamp  Gender  Age              Course YearOfStudy  CGPA  \
# 1     13/7/2020  Female   18       Biotechnology      Year 3   4.0
# 3     13/7/2020  Female   18         Engineering      year 4   4.0
# 5     13/7/2020  Female   19         Engineering      year 4   4.0
# 9     13/7/2020  Female   19         Engineering      year 1   4.0
# 10    13/7/2020  Female   21   Pendidikan Islam       Year 2   4.0
# ..          ...     ...  ...                 ...         ...   ...
# 983  2023-07-08  Female   25                 Kop      year 4   4.0
# 984  2023-07-08  Female   18  Biomedical science      year 1   4.0
# 990  2023-07-08  Female   20                 BIT      Year 3   4.0
# 991  2023-07-09    Male   23                 BIT      Year 3   4.0
# 992  2023-07-09    Male   25                 BIT      Year 3   4.0
#
#      Depression  Anxiety  PanicAttack  SpecialistTreatment  \
# 1             0        1            0                    0
# ...

# %%
#max=df['Price'].max()
#df[df['Price']==max]
