# %%
import tensorflow as tf

# %%
from tensorflow.keras.datasets import california_housing
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-ccf5e62ed7f4> in <cell line: 1>()
# ----> 1 from tensorflow.keras.datasets import california_housing
#
# ImportError: cannot import name 'california_housing' from 'tensorflow.keras.datasets' (/usr/local/lib/python3.10/dist-packages/keras/api/_v2/keras/datasets/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
tf.keras.datasets.california_housing.load_data(
    version="large", path="california_housing.npz", test_split=0.2, seed=113
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-b4b5013a4c92> in <cell line: 1>()
# ----> 1 tf.keras.datasets.california_housing.load_data(
#       2     version="large", path="california_housing.npz", test_split=0.2, seed=113
#       3 )
#
# AttributeError: module 'keras.api._v2.keras.datasets' has no attribute 'california_housing'
